# %% [markdown]
# # Lab 11: ODEs, Failure Rates, and Evolutionary Games

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
from scipy.integrate import odeint
print ('Modules Imported!')
# Out:
# Modules Imported!

# %% [markdown]
# In this lab we're to going analyze evolutionary games using drift analysis. In order to do this, we first need to determine how to integrate ordinary differential equations. So, we begin with a brief exposure of how to achieve this in Python. While we're at it, we'll do a short exercise about failure rate functions.  Then we examine some evolutionary games, using both a stochastic model and a deterministic model, which involves the differential equations.

# %% [markdown]
# ## Integration of ODEs

# %% [markdown]
# This section gives an introdution to integrating ordinary differential equations (odes), with an application to the calculation of a CDF from a failure rate function.  If you recall from your math classes we can describe an ODE as the following:
#
# $\dot{y}=f(y),$
#
# where both $y$ and the function $f$ are vector valued, and $\dot{y}$ is shorthand for $\frac{dy}{dt}.$   The variables being vector valued simply implies that we could have a system of dependent one dimensional (1D) ODEs as opposed to just a single one dimensional variable.  Let's look at the following system:
# $\binom{\dot{y_0}}{\dot{y_1}} = \binom{2y_1-0.1y_0}{-y_0}$
# with the initial condition $y_{init}=\binom{y_1(0)}{y_2(0)}=\binom{1}{1}.$
#
# Our goal in using Python is not to find a closed form solution to the ODE as you would have probably done in your math class, but to numerically integrate it and produce a graphical solution. In order to do this we use the odeint method from scipy.integrate. It takes a function with an initial value and specified times at which the solution is to be output. Internally, the numerical method will often use a much finer grid of time points to solve the ode -- but that is none of your concern.   The times you put in are the times at with the method needs to provide the values of the solution. Look how it is used below:

# %%
# Simple example integrating a 2d ordinary differential equation (ode) dy/dt=f(y,t) 
# Note that the odeint package is imported in the code at the beginning of this file.

# Function to integrate over
def f(y,t):    
    return np.array([2.*y[1]-.1*y[0],-y[0] ])

time=np.linspace(0.0,200.0,10000)   # The times at which the solution is output.
yinit=np.array([1.0,1.0])   # The initial condition
y=odeint(f,yinit,time)      

plt.plot(y[:,0],y[:,1])
plt.title('trajectory of y up to time 200')
plt.ylabel('y_1')
plt.xlabel('y_0')
# Out:
# Text(0.5, 0, 'y_0')

# %% [markdown]
# Typically in a plot like this you would add an arrow to indicate the direction of time in the graph. However, we know the initial state is $y_{init}=\binom{1}{1}.$ So as time increases, the trajectory moves concentrically inwards in a clockwise fashion. Depending on how much of differential equations you remember, this solution should make sense. The equation happens to have a linear form and can be written as $\dot y = Ay$ where
# $
# A=\left( \begin{array}{cc}  -0.1  &  2  \\  -1  & 0 \end{array} \right).
# $
# The eigenvalues of $A$ are complex with negative real parts, so we would expect a decaying oscillatory behavior. (If you didn't follow that, don't worry about it.)
#
# As a simple application of integrating a 1D (one-dimensional) ode, the following code calculates a CDF $F$ from its failure rate function $h.$ But first, let's look at some theory to remember what a failure rate function is. If we let $T$ be a positive random variable with a pdf $f_T$ then
# the failure rate function is defined by the following:
#
# $$h(t)=\lim_{\epsilon \to 0} \frac{P(t<T \leq t+\epsilon | T>t)}{\epsilon}$$
#
# Equivalently, an object having failure rate function $h$ means that for any $t > 0,$ given
# that the object is still working at time $t$, the probability it will fail in the next
# $\epsilon$ time units is $h(t)\epsilon + o(\epsilon)$.  (As usual, $o(\epsilon)$ represents an error term such that $o(\epsilon)/\epsilon \to 0$ as $\epsilon\to 0.$)  With a little bit more derivation (shown in Section 3.9 of your ECE 313 text), we can see that:
#
# $$h(t) = \frac{f_T(t)}{1-F_T(t)}$$
#
# Of course, the pdf $f_T$ is the derivative of the CDF $F_T$. Here's where your 1D ODE comes into play. Given a failure rate function, we want to be able to calculate the CDF. We can easily turn this into an ODE.
#
# $f_T(t) = (1-F_T(t))h(t)$
#
# Let $F_T(t) = y$ and  $f_T(t) = \frac{dy}{dt} = \dot{y}$, then:
#
# $\dot{y} = (1-y)h(t)$
#
# Now we have our differential equation set up and we can solve it by the same method used in the previous example. For the code below, we define a particular bathtub shaped failure rate function to model the lifetime of a component such as a hard disk drive. There is a high, but decreasing initial rate of failure, followed be a period with a very low rate failure, followed by an increasing rate of failure. You should be able to think of reasons why an object might exhibit this type of failure rate function. Notice that the CDF behaves as we would expect: always between 0 and 1, and reactive to $h(t)$.
#
# If you examine the ECE 313 notes you'll see another way to determine $F_T,$  namely, using
# $F_T(t) = 1- \exp \left( \int_o^t -h(s) ds \right)$.  The point here, though, is to get some practice using
# odeint, instead of using this formula.

# %%
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

plt.plot(time,list(map(h,time)))
plt.text(4,h(4)+0.5, r'$h(t)$',fontsize=24) #Plots labels in the graph
plt.text(4,0.5, r'$F(t)$',fontsize=24) 

plt.plot(time,F)
plt.title('failure rate function $h$ and associated CDF, $F$')
plt.axis(ymin=0,ymax=2.0)
plt.ylabel('$h(t), F(t)$',fontsize=20)
plt.xlabel('$t$',fontsize=20)
# Out:
# Text(0.5, 0, '$t$')

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 1:</SPAN>** Using the information on failure rate functions and the example above, do the following:
#
# Write code that, given the failure rate function of a random variable $T$, computes the mean lifetime, $E[T].$  Use this code to determine the mean lifetime for the example given above.  (Hint: An easy way to do this problem is to use the area rule for expectations. Since $T$ is nonnegative, the area rule for expectations gives $E[T]=\int_0^\infty(1-F(t)) dt.$
# The integral $\int_0^\infty (1-F(t)) dt$ is approximately equal to
# $\int_0^{t_{max}} (1-F(t)) dt,$  which, by the definition of Riemann integration, is approximately equal to
# $h \sum_{i=1}^{1000} (1-F(h_i)) $ where $h=t_{max}/1000.$  Basically the code above returns the samples $F(h_i)$ so all you need to do is subtract these values from 1, sum them up and multiply by $h$.)
# What happens to $E[T]$ if the failure rate function is doubled for all time? Print out the new value of $E[T]$.

# %% [markdown]
# __Answer:__ (Your answer here)

# %%
# Your code here
t_max=8.0
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

def cal_mean(F):
    sum = 0
    for i in range(1000):
        sum+=1-F[i][0]
    return 8/1000*sum

mean_1 = cal_mean(F)
print('E[T]:',mean_1)

def new_h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 2*(1-t)
    elif t<3:
        return 0.0
    else:
        return 2*np.sqrt(t-3)
    
def new_Fdot(y,t):    
    return (1-y)*new_h(t)

new_F=odeint(new_Fdot,Finit,time)
mean_2=cal_mean(new_F)
print('new E[T]:',mean_2)
# Out:
# E[T]: 2.6565242198600147
# new E[T]: 1.5504448299973772

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 1</SPAN>**

# %% [markdown]
# ## Evolutionary games (replicator dynamics):

# %% [markdown]
# Consider a population of individuals, where each individual is of some type.  Suppose individuals have occasional pairwise encounters.  During an encounter the two individuals involved play a two player symmetric game in which the strategies are the types of the individuals.   As a result of the encounter, each of the two individuals produces a number of offspring of its same type, with the number being determined by a fitess table or, equivalently, a fitness matrix.   For example, consider a population of crickets such that each cricket is either small or large.   If two small crickets meet each other then they each spawn five more small crickets.  If a small cricket encounters a large cricket then the small cricket spawns one more small cricket and the large cricket spawns eight new large crickets.   If two large crickets meet then each of them spawns three new large crickets.  We can summarize these outcomes using the following table:
# $$\begin{array}{c|cc}  & small & large  \\ \hline
#     small & 5 & 1  \\
#     large & 8 & 3
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  5 & 1 \\ 8 & 3  \end{array}\right).$$
# Associating 0 with "small" and 1 with "large,"  we see that if a type i individual encounters a type j individual, then the type i individual spawns F[i,j] new individuals of type i, and the type j individual spawns F[j,i] new individuals of type j. Below is a stochastic simulation for this game where we start with a population of four small crickets and four large crickets. It may be a useful exercise for you to think of how the values for $a$ and $b$ were created.

# %%
# Stochastic simulation of replicator dynamics for cricket game

F=np.array([[5,1],[8,3]])  # fitness matrix

n=np.array([4,4])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 900 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print ("Round",k+1,"two small crickets meet ", n, n/1./np.sum(n))
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print ("Round",k+1,"a small meets a large   ", n, n/1./np.sum(n))
    else:
        n+=[0,2*F[1,1]]
        print ("Round",k+1,"two large crickets meet ", n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [4 4]        [0.5 0.5]
# Round 1 a small meets a large    [ 5 12] [0.29411765 0.70588235]
# Round 2 a small meets a large    [ 6 20] [0.23076923 0.76923077]
# Round 3 a small meets a large    [ 7 28] [0.2 0.8]
# Round 4 two large crickets meet  [ 7 34] [0.17073171 0.82926829]
# Round 5 a small meets a large    [ 8 42] [0.16 0.84]
# Round 6 a small meets a large    [ 9 50] [0.15254237 0.84745763]
# Round 7 two large crickets meet  [ 9 56] [0.13846154 0.86153846]
# Round 8 a small meets a large    [10 64] [0.13513514 0.86486486]
# Round 9 two large crickets meet  [10 70] [0.125 0.875]
# Round 10 two large crickets meet  [10 76] [0.11627907 0.88372093]
# Round 11 two large crickets meet  [10 82] [0.10869565 0.89130435]
# Round 12 two large crickets meet  [10 88] [0.10204082 0.89795918]
# Round 13 two small crickets meet  [20 88] [0.18518519 0.81481481]
# Round 14 a small meets a large    [21 96] [0.17948718 0.82051282]
# Round 15 a small meets a large    [ 22 104] [0.17460317 0.82539683]
# Round 16 two large crickets meet  [ 22 110] [0.16666667 0.83333333]
# Round 17 two large crickets meet  [ 22 116] [0.15942029 0.84057971]
# Round 18 a small meets a large    [ 23 124] [0.15646259 0.84353741]
# Round 19 two large crickets meet  [ 23 130] [0.1503268 0.8496732]
# Round 20 two large crickets meet  [ 23 136] [0.14465409 0.85534591]
# Round 21 two large crickets meet  [ 23 142] [0.13939394 0.86060606]
# Round 22 a small meets a large    [ 24 150] [0.13793103 0.86206897]
# Round 23 two small crickets meet  [ 34 150] [0.18478261 0.81521739]
# Round 24 two small crickets meet  [ 44 150] [0.22680412 0.77319588]
# Round 25 two large crickets meet  [ 44 156] [0.22 0.78]
# Round 26 two large crickets meet  [ 44 162] [0.21359223 0.78640777]
# Round 27 two small crickets meet  [ 54 162] [0.25 0.75]
# Round 28 two large crickets meet  [ 54 168] [0.24324324 0.75675676]
# Round 29 a small meets a large    [ 55 176] [0.23809524 0.76190476]
# Round 30 a small meets a large    [ 56 184] [0.23333333 0.76666667]
# Round 31 a small meets a large    [ 57 192] [0.22891566 0.77108434]
# Round 32 two large crickets meet  [ 57 198] [0.22352941 0.77647059]
# Round 33 two large crickets meet  [ 57 204] [0.2183908 0.7816092]
# Round 34 two large crickets meet  [ 57 210] [0.21348315 0.78651685]
# Round 35 a small meets a large    [ 58 218] [0.21014493 0.78985507]
# Round 36 two large crickets meet  [ 58 224] [0.20567376 0.79432624]
# Round 37 two large crickets meet  [ 58 230] [0.20138889 0.79861111]
# Round 38 two large crickets meet  [ 58 236] [0.19727891 0.80272109]
# Round 39 a small meets a large    [ 59 244] [0.19471947 0.80528053]
# Round 40 two large crickets meet  [ 59 250] [0.19093851 0.80906149]
# Round 41 two large crickets meet  [ 59 256] [0.18730159 0.81269841]
# Round 42 two large crickets meet  [ 59 262] [0.18380062 0.81619938]
# Round 43 two large crickets meet  [ 59 268] [0.18042813 0.81957187]
# Round 44 two large crickets meet  [ 59 274] [0.17717718 0.82282282]
# Round 45 two large crickets meet  [ 59 280] [0.1740413 0.8259587]
# Round 46 two large crickets meet  [ 59 286] [0.17101449 0.82898551]
# Round 47 a small meets a large    [ 60 294] [0.16949153 0.83050847]
# Round 48 two large crickets meet  [ 60 300] [0.16666667 0.83333333]
# Round 49 a small meets a large    [ 61 308] [0.16531165 0.83468835]
# Round 50 a small meets a large    [ 62 316] [0.16402116 0.83597884]
# Round 51 two large crickets meet  [ 62 322] [0.16145833 0.83854167]
# Round 52 two large crickets meet  [ 62 328] [0.15897436 0.84102564]
# Round 53 two large crickets meet  [ 62 334] [0.15656566 0.84343434]
# Round 54 a small meets a large    [ 63 342] [0.15555556 0.84444444]
# Round 55 two large crickets meet  [ 63 348] [0.15328467 0.84671533]
# Round 56 a small meets a large    [ 64 356] [0.15238095 0.84761905]
# Round 57 two large crickets meet  [ 64 362] [0.15023474 0.84976526]
# Round 58 a small meets a large    [ 65 370] [0.14942529 0.85057471]
# Round 59 two large crickets meet  [ 65 376] [0.14739229 0.85260771]
# Round 60 two large crickets meet  [ 65 382] [0.14541387 0.85458613]
# Round 61 two large crickets meet  [ 65 388] [0.14348786 0.85651214]
# Round 62 two large crickets meet  [ 65 394] [0.1416122 0.8583878]
# Round 63 two large crickets meet  [ 65 400] [0.13978495 0.86021505]
# Round 64 two large crickets meet  [ 65 406] [0.13800425 0.86199575]
# Round 65 two large crickets meet  [ 65 412] [0.13626834 0.86373166]
# Round 66 two large crickets meet  [ 65 418] [0.13457557 0.86542443]
# Round 67 a small meets a large    [ 66 426] [0.13414634 0.86585366]
# Round 68 a small meets a large    [ 67 434] [0.13373253 0.86626747]
# Round 69 two large crickets meet  [ 67 440] [0.1321499 0.8678501]
# Round 70 two large crickets meet  [ 67 446] [0.13060429 0.86939571]
# Round 71 two large crickets meet  [ 67 452] [0.12909441 0.87090559]
# Round 72 two large crickets meet  [ 67 458] [0.12761905 0.87238095]
# Round 73 two large crickets meet  [ 67 464] [0.12617702 0.87382298]
# Round 74 two large crickets meet  [ 67 470] [0.12476723 0.87523277]
# Round 75 two large crickets meet  [ 67 476] [0.12338858 0.87661142]
# Round 76 a small meets a large    [ 68 484] [0.12318841 0.87681159]
# Round 77 two large crickets meet  [ 68 490] [0.1218638 0.8781362]
# Round 78 two large crickets meet  [ 68 496] [0.12056738 0.87943262]
# Round 79 two large crickets meet  [ 68 502] [0.11929825 0.88070175]
# Round 80 a small meets a large    [ 69 510] [0.11917098 0.88082902]
# Round 81 two large crickets meet  [ 69 516] [0.11794872 0.88205128]
# Round 82 two large crickets meet  [ 69 522] [0.11675127 0.88324873]
# Round 83 two large crickets meet  [ 69 528] [0.11557789 0.88442211]
# Round 84 two large crickets meet  [ 69 534] [0.11442786 0.88557214]
# Round 85 two large crickets meet  [ 69 540] [0.11330049 0.88669951]
# Round 86 a small meets a large    [ 70 548] [0.11326861 0.88673139]
# Round 87 two large crickets meet  [ 70 554] [0.11217949 0.88782051]
# Round 88 two large crickets meet  [ 70 560] [0.11111111 0.88888889]
# Round 89 a small meets a large    [ 71 568] [0.11111111 0.88888889]
# Round 90 two large crickets meet  [ 71 574] [0.11007752 0.88992248]
# Round 91 a small meets a large    [ 72 582] [0.11009174 0.88990826]
# Round 92 two large crickets meet  [ 72 588] [0.10909091 0.89090909]
# Round 93 two large crickets meet  [ 72 594] [0.10810811 0.89189189]
# Round 94 a small meets a large    [ 73 602] [0.10814815 0.89185185]
# Round 95 a small meets a large    [ 74 610] [0.10818713 0.89181287]
# Round 96 a small meets a large    [ 75 618] [0.10822511 0.89177489]
# Round 97 two large crickets meet  [ 75 624] [0.10729614 0.89270386]
# Round 98 two large crickets meet  [ 75 630] [0.10638298 0.89361702]
# Round 99 two large crickets meet  [ 75 636] [0.10548523 0.89451477]
# Round 100 a small meets a large    [ 76 644] [0.10555556 0.89444444]
# Round 101 two large crickets meet  [ 76 650] [0.1046832 0.8953168]
# Round 102 two large crickets meet  [ 76 656] [0.10382514 0.89617486]
# Round 103 a small meets a large    [ 77 664] [0.10391363 0.89608637]
# Round 104 a small meets a large    [ 78 672] [0.104 0.896]
# Round 105 two large crickets meet  [ 78 678] [0.1031746 0.8968254]
# Round 106 two large crickets meet  [ 78 684] [0.1023622 0.8976378]
# Round 107 a small meets a large    [ 79 692] [0.10246433 0.89753567]
# Round 108 two large crickets meet  [ 79 698] [0.1016731 0.8983269]
# Round 109 two large crickets meet  [ 79 704] [0.100894 0.899106]
# Round 110 a small meets a large    [ 80 712] [0.1010101 0.8989899]
# Round 111 two large crickets meet  [ 80 718] [0.10025063 0.89974937]
# Round 112 a small meets a large    [ 81 726] [0.10037175 0.89962825]
# Round 113 a small meets a large    [ 82 734] [0.1004902 0.8995098]
# Round 114 a small meets a large    [ 83 742] [0.10060606 0.89939394]
# Round 115 two large crickets meet  [ 83 748] [0.09987966 0.90012034]
# Round 116 two large crickets meet  [ 83 754] [0.09916368 0.90083632]
# Round 117 two large crickets meet  [ 83 760] [0.09845789 0.90154211]
# Round 118 two large crickets meet  [ 83 766] [0.09776207 0.90223793]
# Round 119 two large crickets meet  [ 83 772] [0.09707602 0.90292398]
# Round 120 two large crickets meet  [ 83 778] [0.09639954 0.90360046]
# Round 121 two large crickets meet  [ 83 784] [0.09573241 0.90426759]
# Round 122 two large crickets meet  [ 83 790] [0.09507446 0.90492554]
# Round 123 two large crickets meet  [ 83 796] [0.09442548 0.90557452]
# Round 124 two large crickets meet  [ 83 802] [0.09378531 0.90621469]
# Round 125 two large crickets meet  [ 83 808] [0.09315376 0.90684624]
# Round 126 two large crickets meet  [ 83 814] [0.09253066 0.90746934]
# Round 127 two large crickets meet  [ 83 820] [0.09191584 0.90808416]
# Round 128 a small meets a large    [ 84 828] [0.09210526 0.90789474]
# Round 129 two large crickets meet  [ 84 834] [0.09150327 0.90849673]
# Round 130 a small meets a large    [ 85 842] [0.09169364 0.90830636]
# Round 131 two large crickets meet  [ 85 848] [0.09110397 0.90889603]
# Round 132 a small meets a large    [ 86 856] [0.09129512 0.90870488]
# Round 133 two large crickets meet  [ 86 862] [0.0907173 0.9092827]
# Round 134 two large crickets meet  [ 86 868] [0.09014675 0.90985325]
# Round 135 two large crickets meet  [ 86 874] [0.08958333 0.91041667]
# Round 136 two large crickets meet  [ 86 880] [0.08902692 0.91097308]
# Round 137 a small meets a large    [ 87 888] [0.08923077 0.91076923]
# Round 138 two large crickets meet  [ 87 894] [0.08868502 0.91131498]
# Round 139 a small meets a large    [ 88 902] [0.08888889 0.91111111]
# Round 140 two large crickets meet  [ 88 908] [0.08835341 0.91164659]
# Round 141 two large crickets meet  [ 88 914] [0.08782435 0.91217565]
# Round 142 two large crickets meet  [ 88 920] [0.08730159 0.91269841]
# Round 143 two large crickets meet  [ 88 926] [0.08678501 0.91321499]
# Round 144 a small meets a large    [ 89 934] [0.08699902 0.91300098]
# Round 145 two large crickets meet  [ 89 940] [0.08649174 0.91350826]
# Round 146 two large crickets meet  [ 89 946] [0.08599034 0.91400966]
# Round 147 two large crickets meet  [ 89 952] [0.08549472 0.91450528]
# Round 148 two large crickets meet  [ 89 958] [0.08500478 0.91499522]
# Round 149 two large crickets meet  [ 89 964] [0.08452042 0.91547958]
# Round 150 two large crickets meet  [ 89 970] [0.08404155 0.91595845]
# Round 151 two large crickets meet  [ 89 976] [0.08356808 0.91643192]
# Round 152 two large crickets meet  [ 89 982] [0.08309991 0.91690009]
# Round 153 a small meets a large    [ 90 990] [0.08333333 0.91666667]
# Round 154 two large crickets meet  [ 90 996] [0.08287293 0.91712707]
# Round 155 two large crickets meet  [  90 1002] [0.08241758 0.91758242]
# Round 156 two large crickets meet  [  90 1008] [0.08196721 0.91803279]
# Round 157 two large crickets meet  [  90 1014] [0.08152174 0.91847826]
# Round 158 two large crickets meet  [  90 1020] [0.08108108 0.91891892]
# Round 159 two large crickets meet  [  90 1026] [0.08064516 0.91935484]
# Round 160 two large crickets meet  [  90 1032] [0.0802139 0.9197861]
# Round 161 two large crickets meet  [  90 1038] [0.07978723 0.92021277]
# Round 162 two large crickets meet  [  90 1044] [0.07936508 0.92063492]
# Round 163 two large crickets meet  [  90 1050] [0.07894737 0.92105263]
# Round 164 two large crickets meet  [  90 1056] [0.07853403 0.92146597]
# Round 165 a small meets a large    [  91 1064] [0.07878788 0.92121212]
# Round 166 two large crickets meet  [  91 1070] [0.07838071 0.92161929]
# Round 167 a small meets a large    [  92 1078] [0.07863248 0.92136752]
# Round 168 two large crickets meet  [  92 1084] [0.07823129 0.92176871]
# Round 169 two large crickets meet  [  92 1090] [0.07783418 0.92216582]
# Round 170 two large crickets meet  [  92 1096] [0.07744108 0.92255892]
# Round 171 two large crickets meet  [  92 1102] [0.07705193 0.92294807]
# Round 172 two large crickets meet  [  92 1108] [0.07666667 0.92333333]
# Round 173 two large crickets meet  [  92 1114] [0.07628524 0.92371476]
# Round 174 two large crickets meet  [  92 1120] [0.07590759 0.92409241]
# Round 175 a small meets a large    [  93 1128] [0.07616708 0.92383292]
# Round 176 two large crickets meet  [  93 1134] [0.07579462 0.92420538]
# Round 177 two large crickets meet  [  93 1140] [0.07542579 0.92457421]
# Round 178 a small meets a large    [  94 1148] [0.07568438 0.92431562]
# Round 179 two large crickets meet  [  94 1154] [0.07532051 0.92467949]
# Round 180 two large crickets meet  [  94 1160] [0.07496013 0.92503987]
# Round 181 two large crickets meet  [  94 1166] [0.07460317 0.92539683]
# Round 182 two large crickets meet  [  94 1172] [0.07424961 0.92575039]
# Round 183 two large crickets meet  [  94 1178] [0.07389937 0.92610063]
# Round 184 two large crickets meet  [  94 1184] [0.07355243 0.92644757]
# Round 185 two large crickets meet  [  94 1190] [0.07320872 0.92679128]
# Round 186 two large crickets meet  [  94 1196] [0.07286822 0.92713178]
# Round 187 two large crickets meet  [  94 1202] [0.07253086 0.92746914]
# Round 188 two large crickets meet  [  94 1208] [0.07219662 0.92780338]
# Round 189 two large crickets meet  [  94 1214] [0.07186544 0.92813456]
# Round 190 two large crickets meet  [  94 1220] [0.07153729 0.92846271]
# Round 191 two large crickets meet  [  94 1226] [0.07121212 0.92878788]
# Round 192 two large crickets meet  [  94 1232] [0.07088989 0.92911011]
# Round 193 two large crickets meet  [  94 1238] [0.07057057 0.92942943]
# Round 194 two large crickets meet  [  94 1244] [0.07025411 0.92974589]
# Round 195 two large crickets meet  [  94 1250] [0.06994048 0.93005952]
# Round 196 two large crickets meet  [  94 1256] [0.06962963 0.93037037]
# Round 197 a small meets a large    [  95 1264] [0.06990434 0.93009566]
# Round 198 two large crickets meet  [  95 1270] [0.06959707 0.93040293]
# Round 199 two large crickets meet  [  95 1276] [0.06929249 0.93070751]
# Round 200 two large crickets meet  [  95 1282] [0.06899056 0.93100944]
# Round 201 a small meets a large    [  96 1290] [0.06926407 0.93073593]
# Round 202 two large crickets meet  [  96 1296] [0.06896552 0.93103448]
# Round 203 two large crickets meet  [  96 1302] [0.06866953 0.93133047]
# Round 204 a small meets a large    [  97 1310] [0.06894101 0.93105899]
# Round 205 two large crickets meet  [  97 1316] [0.06864827 0.93135173]
# Round 206 two large crickets meet  [  97 1322] [0.068358 0.931642]
# Round 207 two large crickets meet  [  97 1328] [0.06807018 0.93192982]
# Round 208 two large crickets meet  [  97 1334] [0.06778477 0.93221523]
# Round 209 two small crickets meet  [ 107 1334] [0.07425399 0.92574601]
# Round 210 two large crickets meet  [ 107 1340] [0.0739461 0.9260539]
# Round 211 a small meets a large    [ 108 1348] [0.07417582 0.92582418]
# Round 212 two large crickets meet  [ 108 1354] [0.07387141 0.92612859]
# Round 213 two large crickets meet  [ 108 1360] [0.07356948 0.92643052]
# Round 214 two large crickets meet  [ 108 1366] [0.07327001 0.92672999]
# Round 215 two large crickets meet  [ 108 1372] [0.07297297 0.92702703]
# Round 216 two large crickets meet  [ 108 1378] [0.07267833 0.92732167]
# Round 217 two large crickets meet  [ 108 1384] [0.07238606 0.92761394]
# Round 218 two large crickets meet  [ 108 1390] [0.07209613 0.92790387]
# Round 219 a small meets a large    [ 109 1398] [0.07232913 0.92767087]
# Round 220 two large crickets meet  [ 109 1404] [0.0720423 0.9279577]
# Round 221 two large crickets meet  [ 109 1410] [0.07175774 0.92824226]
# Round 222 two large crickets meet  [ 109 1416] [0.07147541 0.92852459]
# Round 223 two large crickets meet  [ 109 1422] [0.0711953 0.9288047]
# Round 224 two large crickets meet  [ 109 1428] [0.07091737 0.92908263]
# Round 225 two large crickets meet  [ 109 1434] [0.07064161 0.92935839]
# Round 226 two large crickets meet  [ 109 1440] [0.07036798 0.92963202]
# Round 227 two large crickets meet  [ 109 1446] [0.07009646 0.92990354]
# Round 228 a small meets a large    [ 110 1454] [0.07033248 0.92966752]
# Round 229 two large crickets meet  [ 110 1460] [0.07006369 0.92993631]
# Round 230 two large crickets meet  [ 110 1466] [0.06979695 0.93020305]
# Round 231 two large crickets meet  [ 110 1472] [0.06953224 0.93046776]
# Round 232 two large crickets meet  [ 110 1478] [0.06926952 0.93073048]
# Round 233 two large crickets meet  [ 110 1484] [0.06900878 0.93099122]
# Round 234 two large crickets meet  [ 110 1490] [0.06875 0.93125]
# Round 235 two large crickets meet  [ 110 1496] [0.06849315 0.93150685]
# Round 236 two large crickets meet  [ 110 1502] [0.06823821 0.93176179]
# Round 237 two large crickets meet  [ 110 1508] [0.06798517 0.93201483]
# Round 238 two large crickets meet  [ 110 1514] [0.06773399 0.93226601]
# Round 239 two large crickets meet  [ 110 1520] [0.06748466 0.93251534]
# Round 240 two large crickets meet  [ 110 1526] [0.06723716 0.93276284]
# Round 241 two large crickets meet  [ 110 1532] [0.06699147 0.93300853]
# Round 242 two large crickets meet  [ 110 1538] [0.06674757 0.93325243]
# Round 243 two large crickets meet  [ 110 1544] [0.06650544 0.93349456]
# Round 244 a small meets a large    [ 111 1552] [0.06674684 0.93325316]
# Round 245 a small meets a large    [ 112 1560] [0.06698565 0.93301435]
# Round 246 two large crickets meet  [ 112 1566] [0.06674613 0.93325387]
# Round 247 two large crickets meet  [ 112 1572] [0.06650831 0.93349169]
# Round 248 two large crickets meet  [ 112 1578] [0.06627219 0.93372781]
# Round 249 two large crickets meet  [ 112 1584] [0.06603774 0.93396226]
# Round 250 two large crickets meet  [ 112 1590] [0.06580494 0.93419506]
# Round 251 two large crickets meet  [ 112 1596] [0.06557377 0.93442623]
# Round 252 two large crickets meet  [ 112 1602] [0.06534422 0.93465578]
# Round 253 two large crickets meet  [ 112 1608] [0.06511628 0.93488372]
# Round 254 two large crickets meet  [ 112 1614] [0.06488992 0.93511008]
# Round 255 two large crickets meet  [ 112 1620] [0.06466513 0.93533487]
# Round 256 two large crickets meet  [ 112 1626] [0.06444189 0.93555811]
# Round 257 two large crickets meet  [ 112 1632] [0.06422018 0.93577982]
# Round 258 two large crickets meet  [ 112 1638] [0.064 0.936]
# Round 259 a small meets a large    [ 113 1646] [0.06424105 0.93575895]
# Round 260 two large crickets meet  [ 113 1652] [0.06402266 0.93597734]
# Round 261 two large crickets meet  [ 113 1658] [0.06380576 0.93619424]
# Round 262 two large crickets meet  [ 113 1664] [0.06359032 0.93640968]
# Round 263 two large crickets meet  [ 113 1670] [0.06337633 0.93662367]
# Round 264 a small meets a large    [ 114 1678] [0.06361607 0.93638393]
# Round 265 two large crickets meet  [ 114 1684] [0.06340378 0.93659622]
# Round 266 a small meets a large    [ 115 1692] [0.06364139 0.93635861]
# Round 267 two large crickets meet  [ 115 1698] [0.06343078 0.93656922]
# Round 268 a small meets a large    [ 116 1706] [0.0636663 0.9363337]
# Round 269 a small meets a large    [ 117 1714] [0.06389951 0.93610049]
# Round 270 two large crickets meet  [ 117 1720] [0.0636908 0.9363092]
# Round 271 two large crickets meet  [ 117 1726] [0.06348345 0.93651655]
# Round 272 two large crickets meet  [ 117 1732] [0.06327745 0.93672255]
# Round 273 a small meets a large    [ 118 1740] [0.06350915 0.93649085]
# Round 274 two large crickets meet  [ 118 1746] [0.06330472 0.93669528]
# Round 275 two large crickets meet  [ 118 1752] [0.0631016 0.9368984]
# Round 276 two large crickets meet  [ 118 1758] [0.06289979 0.93710021]
# Round 277 two large crickets meet  [ 118 1764] [0.06269926 0.93730074]
# Round 278 two large crickets meet  [ 118 1770] [0.0625 0.9375]
# Round 279 two large crickets meet  [ 118 1776] [0.06230201 0.93769799]
# Round 280 two large crickets meet  [ 118 1782] [0.06210526 0.93789474]
# Round 281 a small meets a large    [ 119 1790] [0.0623363 0.9376637]
# Round 282 two large crickets meet  [ 119 1796] [0.06214099 0.93785901]
# Round 283 two large crickets meet  [ 119 1802] [0.0619469 0.9380531]
# Round 284 two large crickets meet  [ 119 1808] [0.06175402 0.93824598]
# Round 285 two large crickets meet  [ 119 1814] [0.06156234 0.93843766]
# Round 286 two large crickets meet  [ 119 1820] [0.06137184 0.93862816]
# Round 287 two large crickets meet  [ 119 1826] [0.06118252 0.93881748]
# Round 288 two large crickets meet  [ 119 1832] [0.06099436 0.93900564]
# Round 289 two large crickets meet  [ 119 1838] [0.06080736 0.93919264]
# Round 290 two large crickets meet  [ 119 1844] [0.0606215 0.9393785]
# Round 291 two large crickets meet  [ 119 1850] [0.06043677 0.93956323]
# Round 292 two large crickets meet  [ 119 1856] [0.06025316 0.93974684]
# Round 293 a small meets a large    [ 120 1864] [0.06048387 0.93951613]
# Round 294 two large crickets meet  [ 120 1870] [0.06030151 0.93969849]
# Round 295 two large crickets meet  [ 120 1876] [0.06012024 0.93987976]
# Round 296 two large crickets meet  [ 120 1882] [0.05994006 0.94005994]
# Round 297 two large crickets meet  [ 120 1888] [0.05976096 0.94023904]
# Round 298 two large crickets meet  [ 120 1894] [0.05958292 0.94041708]
# Round 299 a small meets a large    [ 121 1902] [0.05981216 0.94018784]
# Round 300 two large crickets meet  [ 121 1908] [0.05963529 0.94036471]
# Round 301 two large crickets meet  [ 121 1914] [0.05945946 0.94054054]
# Round 302 two large crickets meet  [ 121 1920] [0.05928466 0.94071534]
# Round 303 two large crickets meet  [ 121 1926] [0.05911089 0.94088911]
# Round 304 two large crickets meet  [ 121 1932] [0.05893814 0.94106186]
# Round 305 two large crickets meet  [ 121 1938] [0.05876639 0.94123361]
# Round 306 a small meets a large    [ 122 1946] [0.0589942 0.9410058]
# Round 307 two large crickets meet  [ 122 1952] [0.05882353 0.94117647]
# Round 308 two large crickets meet  [ 122 1958] [0.05865385 0.94134615]
# Round 309 two large crickets meet  [ 122 1964] [0.05848514 0.94151486]
# Round 310 two large crickets meet  [ 122 1970] [0.0583174 0.9416826]
# Round 311 two large crickets meet  [ 122 1976] [0.05815062 0.94184938]
# Round 312 a small meets a large    [ 123 1984] [0.05837684 0.94162316]
# Round 313 two large crickets meet  [ 123 1990] [0.05821107 0.94178893]
# Round 314 two large crickets meet  [ 123 1996] [0.05804625 0.94195375]
# Round 315 two large crickets meet  [ 123 2002] [0.05788235 0.94211765]
# Round 316 a small meets a large    [ 124 2010] [0.05810684 0.94189316]
# Round 317 two large crickets meet  [ 124 2016] [0.05794393 0.94205607]
# Round 318 a small meets a large    [ 125 2024] [0.05816659 0.94183341]
# Round 319 two large crickets meet  [ 125 2030] [0.05800464 0.94199536]
# Round 320 a small meets a large    [ 126 2038] [0.05822551 0.94177449]
# Round 321 two large crickets meet  [ 126 2044] [0.05806452 0.94193548]
# Round 322 two large crickets meet  [ 126 2050] [0.05790441 0.94209559]
# Round 323 two large crickets meet  [ 126 2056] [0.05774519 0.94225481]
# Round 324 two large crickets meet  [ 126 2062] [0.05758684 0.94241316]
# Round 325 two large crickets meet  [ 126 2068] [0.05742935 0.94257065]
# Round 326 two large crickets meet  [ 126 2074] [0.05727273 0.94272727]
# Round 327 two large crickets meet  [ 126 2080] [0.05711695 0.94288305]
# Round 328 two large crickets meet  [ 126 2086] [0.05696203 0.94303797]
# Round 329 two large crickets meet  [ 126 2092] [0.05680794 0.94319206]
# Round 330 two large crickets meet  [ 126 2098] [0.05665468 0.94334532]
# Round 331 two large crickets meet  [ 126 2104] [0.05650224 0.94349776]
# Round 332 two large crickets meet  [ 126 2110] [0.05635063 0.94364937]
# Round 333 two large crickets meet  [ 126 2116] [0.05619982 0.94380018]
# Round 334 a small meets a large    [ 127 2124] [0.05641937 0.94358063]
# Round 335 two large crickets meet  [ 127 2130] [0.05626938 0.94373062]
# Round 336 two large crickets meet  [ 127 2136] [0.05612019 0.94387981]
# Round 337 two large crickets meet  [ 127 2142] [0.05597179 0.94402821]
# Round 338 two large crickets meet  [ 127 2148] [0.05582418 0.94417582]
# Round 339 two large crickets meet  [ 127 2154] [0.05567733 0.94432267]
# Round 340 a small meets a large    [ 128 2162] [0.0558952 0.9441048]
# Round 341 two large crickets meet  [ 128 2168] [0.05574913 0.94425087]
# Round 342 two large crickets meet  [ 128 2174] [0.05560382 0.94439618]
# Round 343 two large crickets meet  [ 128 2180] [0.05545927 0.94454073]
# Round 344 two large crickets meet  [ 128 2186] [0.05531547 0.94468453]
# Round 345 two large crickets meet  [ 128 2192] [0.05517241 0.94482759]
# Round 346 two small crickets meet  [ 138 2192] [0.05922747 0.94077253]
# Round 347 two large crickets meet  [ 138 2198] [0.05907534 0.94092466]
# Round 348 two large crickets meet  [ 138 2204] [0.058924 0.941076]
# Round 349 two large crickets meet  [ 138 2210] [0.05877342 0.94122658]
# Round 350 two large crickets meet  [ 138 2216] [0.05862362 0.94137638]
# Round 351 two large crickets meet  [ 138 2222] [0.05847458 0.94152542]
# Round 352 two large crickets meet  [ 138 2228] [0.05832629 0.94167371]
# Round 353 two large crickets meet  [ 138 2234] [0.05817875 0.94182125]
# Round 354 two large crickets meet  [ 138 2240] [0.05803196 0.94196804]
# Round 355 two large crickets meet  [ 138 2246] [0.05788591 0.94211409]
# Round 356 two large crickets meet  [ 138 2252] [0.05774059 0.94225941]
# Round 357 two large crickets meet  [ 138 2258] [0.05759599 0.94240401]
# Round 358 two large crickets meet  [ 138 2264] [0.05745212 0.94254788]
# Round 359 a small meets a large    [ 139 2272] [0.05765243 0.94234757]
# Round 360 two large crickets meet  [ 139 2278] [0.05750931 0.94249069]
# Round 361 two large crickets meet  [ 139 2284] [0.0573669 0.9426331]
# Round 362 two large crickets meet  [ 139 2290] [0.0572252 0.9427748]
# Round 363 two large crickets meet  [ 139 2296] [0.05708419 0.94291581]
# Round 364 two large crickets meet  [ 139 2302] [0.05694388 0.94305612]
# Round 365 two large crickets meet  [ 139 2308] [0.05680425 0.94319575]
# Round 366 two large crickets meet  [ 139 2314] [0.05666531 0.94333469]
# Round 367 a small meets a large    [ 140 2322] [0.05686434 0.94313566]
# Round 368 two large crickets meet  [ 140 2328] [0.05672609 0.94327391]
# Round 369 two large crickets meet  [ 140 2334] [0.05658852 0.94341148]
# Round 370 two large crickets meet  [ 140 2340] [0.05645161 0.94354839]
# Round 371 two large crickets meet  [ 140 2346] [0.05631537 0.94368463]
# Round 372 two large crickets meet  [ 140 2352] [0.05617978 0.94382022]
# Round 373 a small meets a large    [ 141 2360] [0.05637745 0.94362255]
# Round 374 two large crickets meet  [ 141 2366] [0.05624252 0.94375748]
# Round 375 a small meets a large    [ 142 2374] [0.05643879 0.94356121]
# Round 376 two large crickets meet  [ 142 2380] [0.05630452 0.94369548]
# Round 377 two large crickets meet  [ 142 2386] [0.05617089 0.94382911]
# Round 378 two large crickets meet  [ 142 2392] [0.05603788 0.94396212]
# Round 379 two large crickets meet  [ 142 2398] [0.05590551 0.94409449]
# Round 380 two large crickets meet  [ 142 2404] [0.05577376 0.94422624]
# Round 381 two large crickets meet  [ 142 2410] [0.05564263 0.94435737]
# Round 382 two large crickets meet  [ 142 2416] [0.05551212 0.94448788]
# Round 383 two large crickets meet  [ 142 2422] [0.05538222 0.94461778]
# Round 384 two large crickets meet  [ 142 2428] [0.05525292 0.94474708]
# Round 385 two large crickets meet  [ 142 2434] [0.05512422 0.94487578]
# Round 386 two large crickets meet  [ 142 2440] [0.05499613 0.94500387]
# Round 387 two large crickets meet  [ 142 2446] [0.05486862 0.94513138]
# Round 388 two large crickets meet  [ 142 2452] [0.05474171 0.94525829]
# Round 389 two large crickets meet  [ 142 2458] [0.05461538 0.94538462]
# Round 390 two large crickets meet  [ 142 2464] [0.05448964 0.94551036]
# Round 391 two large crickets meet  [ 142 2470] [0.05436447 0.94563553]
# Round 392 two large crickets meet  [ 142 2476] [0.05423988 0.94576012]
# Round 393 two large crickets meet  [ 142 2482] [0.05411585 0.94588415]
# Round 394 two large crickets meet  [ 142 2488] [0.0539924 0.9460076]
# Round 395 two large crickets meet  [ 142 2494] [0.0538695 0.9461305]
# Round 396 two large crickets meet  [ 142 2500] [0.05374716 0.94625284]
# Round 397 two large crickets meet  [ 142 2506] [0.05362538 0.94637462]
# Round 398 two large crickets meet  [ 142 2512] [0.05350414 0.94649586]
# Round 399 two large crickets meet  [ 142 2518] [0.05338346 0.94661654]
# Round 400 two large crickets meet  [ 142 2524] [0.05326332 0.94673668]
# Round 401 a small meets a large    [ 143 2532] [0.05345794 0.94654206]
# Round 402 two large crickets meet  [ 143 2538] [0.05333831 0.94666169]
# Round 403 two large crickets meet  [ 143 2544] [0.0532192 0.9467808]
# Round 404 two large crickets meet  [ 143 2550] [0.05310063 0.94689937]
# Round 405 a small meets a large    [ 144 2558] [0.05329386 0.94670614]
# Round 406 two large crickets meet  [ 144 2564] [0.05317578 0.94682422]
# Round 407 two large crickets meet  [ 144 2570] [0.05305822 0.94694178]
# Round 408 two large crickets meet  [ 144 2576] [0.05294118 0.94705882]
# Round 409 two large crickets meet  [ 144 2582] [0.05282465 0.94717535]
# Round 410 two large crickets meet  [ 144 2588] [0.05270864 0.94729136]
# Round 411 two large crickets meet  [ 144 2594] [0.05259313 0.94740687]
# Round 412 two large crickets meet  [ 144 2600] [0.05247813 0.94752187]
# Round 413 two large crickets meet  [ 144 2606] [0.05236364 0.94763636]
# Round 414 two large crickets meet  [ 144 2612] [0.05224964 0.94775036]
# Round 415 two large crickets meet  [ 144 2618] [0.05213613 0.94786387]
# Round 416 two large crickets meet  [ 144 2624] [0.05202312 0.94797688]
# Round 417 a small meets a large    [ 145 2632] [0.05221462 0.94778538]
# Round 418 two large crickets meet  [ 145 2638] [0.05210205 0.94789795]
# Round 419 two large crickets meet  [ 145 2644] [0.05198996 0.94801004]
# Round 420 two large crickets meet  [ 145 2650] [0.05187835 0.94812165]
# Round 421 two large crickets meet  [ 145 2656] [0.05176723 0.94823277]
# Round 422 two large crickets meet  [ 145 2662] [0.05165657 0.94834343]
# Round 423 two large crickets meet  [ 145 2668] [0.05154639 0.94845361]
# Round 424 two large crickets meet  [ 145 2674] [0.05143668 0.94856332]
# Round 425 two large crickets meet  [ 145 2680] [0.05132743 0.94867257]
# Round 426 two large crickets meet  [ 145 2686] [0.05121865 0.94878135]
# Round 427 two large crickets meet  [ 145 2692] [0.05111033 0.94888967]
# Round 428 two large crickets meet  [ 145 2698] [0.05100246 0.94899754]
# Round 429 two large crickets meet  [ 145 2704] [0.05089505 0.94910495]
# Round 430 two large crickets meet  [ 145 2710] [0.05078809 0.94921191]
# Round 431 two large crickets meet  [ 145 2716] [0.05068158 0.94931842]
# Round 432 two large crickets meet  [ 145 2722] [0.05057551 0.94942449]
# Round 433 two large crickets meet  [ 145 2728] [0.05046989 0.94953011]
# Round 434 two large crickets meet  [ 145 2734] [0.05036471 0.94963529]
# Round 435 two large crickets meet  [ 145 2740] [0.05025997 0.94974003]
# Round 436 two large crickets meet  [ 145 2746] [0.05015566 0.94984434]
# Round 437 two large crickets meet  [ 145 2752] [0.05005178 0.94994822]
# Round 438 two large crickets meet  [ 145 2758] [0.04994833 0.95005167]
# Round 439 two large crickets meet  [ 145 2764] [0.04984531 0.95015469]
# Round 440 two large crickets meet  [ 145 2770] [0.04974271 0.95025729]
# Round 441 two large crickets meet  [ 145 2776] [0.04964053 0.95035947]
# Round 442 two large crickets meet  [ 145 2782] [0.04953878 0.95046122]
# Round 443 two large crickets meet  [ 145 2788] [0.04943744 0.95056256]
# Round 444 two large crickets meet  [ 145 2794] [0.04933651 0.95066349]
# Round 445 two large crickets meet  [ 145 2800] [0.04923599 0.95076401]
# Round 446 two large crickets meet  [ 145 2806] [0.04913589 0.95086411]
# Round 447 two large crickets meet  [ 145 2812] [0.04903619 0.95096381]
# Round 448 two large crickets meet  [ 145 2818] [0.04893689 0.95106311]
# Round 449 two large crickets meet  [ 145 2824] [0.04883799 0.95116201]
# Round 450 two large crickets meet  [ 145 2830] [0.0487395 0.9512605]
# Round 451 two large crickets meet  [ 145 2836] [0.0486414 0.9513586]
# Round 452 two large crickets meet  [ 145 2842] [0.04854369 0.95145631]
# Round 453 two large crickets meet  [ 145 2848] [0.04844637 0.95155363]
# Round 454 two large crickets meet  [ 145 2854] [0.04834945 0.95165055]
# Round 455 two large crickets meet  [ 145 2860] [0.04825291 0.95174709]
# Round 456 two large crickets meet  [ 145 2866] [0.04815676 0.95184324]
# Round 457 two large crickets meet  [ 145 2872] [0.04806099 0.95193901]
# Round 458 two large crickets meet  [ 145 2878] [0.0479656 0.9520344]
# Round 459 two large crickets meet  [ 145 2884] [0.04787058 0.95212942]
# Round 460 a small meets a large    [ 146 2892] [0.04805793 0.95194207]
# Round 461 two large crickets meet  [ 146 2898] [0.04796321 0.95203679]
# Round 462 two large crickets meet  [ 146 2904] [0.04786885 0.95213115]
# Round 463 two large crickets meet  [ 146 2910] [0.04777487 0.95222513]
# Round 464 two large crickets meet  [ 146 2916] [0.04768125 0.95231875]
# Round 465 two large crickets meet  [ 146 2922] [0.04758801 0.95241199]
# Round 466 two large crickets meet  [ 146 2928] [0.04749512 0.95250488]
# Round 467 two large crickets meet  [ 146 2934] [0.0474026 0.9525974]
# Round 468 two large crickets meet  [ 146 2940] [0.04731043 0.95268957]
# Round 469 two large crickets meet  [ 146 2946] [0.04721863 0.95278137]
# Round 470 a small meets a large    [ 147 2954] [0.04740406 0.95259594]
# Round 471 two large crickets meet  [ 147 2960] [0.04731252 0.95268748]
# Round 472 two large crickets meet  [ 147 2966] [0.04722133 0.95277867]
# Round 473 two large crickets meet  [ 147 2972] [0.04713049 0.95286951]
# Round 474 two large crickets meet  [ 147 2978] [0.04704 0.95296]
# Round 475 two large crickets meet  [ 147 2984] [0.04694986 0.95305014]
# Round 476 two large crickets meet  [ 147 2990] [0.04686006 0.95313994]
# Round 477 two large crickets meet  [ 147 2996] [0.0467706 0.9532294]
# Round 478 two large crickets meet  [ 147 3002] [0.04668149 0.95331851]
# Round 479 two large crickets meet  [ 147 3008] [0.04659271 0.95340729]
# Round 480 two large crickets meet  [ 147 3014] [0.04650427 0.95349573]
# Round 481 two large crickets meet  [ 147 3020] [0.04641617 0.95358383]
# Round 482 two large crickets meet  [ 147 3026] [0.0463284 0.9536716]
# Round 483 two large crickets meet  [ 147 3032] [0.04624096 0.95375904]
# Round 484 two large crickets meet  [ 147 3038] [0.04615385 0.95384615]
# Round 485 two large crickets meet  [ 147 3044] [0.04606706 0.95393294]
# Round 486 two large crickets meet  [ 147 3050] [0.04598061 0.95401939]
# Round 487 two large crickets meet  [ 147 3056] [0.04589447 0.95410553]
# Round 488 two large crickets meet  [ 147 3062] [0.04580866 0.95419134]
# Round 489 two large crickets meet  [ 147 3068] [0.04572317 0.95427683]
# Round 490 two large crickets meet  [ 147 3074] [0.045638 0.954362]
# Round 491 two large crickets meet  [ 147 3080] [0.04555315 0.95444685]
# Round 492 two large crickets meet  [ 147 3086] [0.04546861 0.95453139]
# Round 493 two large crickets meet  [ 147 3092] [0.04538438 0.95461562]
# Round 494 two large crickets meet  [ 147 3098] [0.04530046 0.95469954]
# Round 495 a small meets a large    [ 148 3106] [0.04548248 0.95451752]
# Round 496 two large crickets meet  [ 148 3112] [0.04539877 0.95460123]
# Round 497 two large crickets meet  [ 148 3118] [0.04531537 0.95468463]
# Round 498 a small meets a large    [ 149 3126] [0.04549618 0.95450382]
# Round 499 two large crickets meet  [ 149 3132] [0.04541298 0.95458702]
# Round 500 two large crickets meet  [ 149 3138] [0.04533009 0.95466991]
# Round 501 two large crickets meet  [ 149 3144] [0.04524749 0.95475251]
# Round 502 two large crickets meet  [ 149 3150] [0.0451652 0.9548348]
# Round 503 two large crickets meet  [ 149 3156] [0.04508321 0.95491679]
# Round 504 two large crickets meet  [ 149 3162] [0.04500151 0.95499849]
# Round 505 two large crickets meet  [ 149 3168] [0.04492011 0.95507989]
# Round 506 two large crickets meet  [ 149 3174] [0.044839 0.955161]
# Round 507 two large crickets meet  [ 149 3180] [0.04475819 0.95524181]
# Round 508 two large crickets meet  [ 149 3186] [0.04467766 0.95532234]
# Round 509 two large crickets meet  [ 149 3192] [0.04459743 0.95540257]
# Round 510 two large crickets meet  [ 149 3198] [0.04451748 0.95548252]
# Round 511 two large crickets meet  [ 149 3204] [0.04443782 0.95556218]
# Round 512 two large crickets meet  [ 149 3210] [0.04435844 0.95564156]
# Round 513 two large crickets meet  [ 149 3216] [0.04427935 0.95572065]
# Round 514 two large crickets meet  [ 149 3222] [0.04420053 0.95579947]
# Round 515 two large crickets meet  [ 149 3228] [0.044122 0.955878]
# Round 516 two large crickets meet  [ 149 3234] [0.04404375 0.95595625]
# Round 517 two large crickets meet  [ 149 3240] [0.04396577 0.95603423]
# Round 518 two large crickets meet  [ 149 3246] [0.04388807 0.95611193]
# Round 519 a small meets a large    [ 150 3254] [0.0440658 0.9559342]
# Round 520 two large crickets meet  [ 150 3260] [0.04398827 0.95601173]
# Round 521 two large crickets meet  [ 150 3266] [0.04391101 0.95608899]
# Round 522 a small meets a large    [ 151 3274] [0.04408759 0.95591241]
# Round 523 two large crickets meet  [ 151 3280] [0.04401049 0.95598951]
# Round 524 two large crickets meet  [ 151 3286] [0.04393366 0.95606634]
# Round 525 two large crickets meet  [ 151 3292] [0.0438571 0.9561429]
# Round 526 two large crickets meet  [ 151 3298] [0.04378081 0.95621919]
# Round 527 a small meets a large    [ 152 3306] [0.04395604 0.95604396]
# Round 528 two large crickets meet  [ 152 3312] [0.04387991 0.95612009]
# Round 529 two large crickets meet  [ 152 3318] [0.04380403 0.95619597]
# Round 530 a small meets a large    [ 153 3326] [0.04397815 0.95602185]
# Round 531 two large crickets meet  [ 153 3332] [0.04390244 0.95609756]
# Round 532 two large crickets meet  [ 153 3338] [0.04382698 0.95617302]
# Round 533 two large crickets meet  [ 153 3344] [0.04375179 0.95624821]
# Round 534 two large crickets meet  [ 153 3350] [0.04367685 0.95632315]
# Round 535 two large crickets meet  [ 153 3356] [0.04360217 0.95639783]
# Round 536 two large crickets meet  [ 153 3362] [0.04352774 0.95647226]
# Round 537 two large crickets meet  [ 153 3368] [0.04345356 0.95654644]
# Round 538 two large crickets meet  [ 153 3374] [0.04337964 0.95662036]
# Round 539 two large crickets meet  [ 153 3380] [0.04330597 0.95669403]
# Round 540 two large crickets meet  [ 153 3386] [0.04323255 0.95676745]
# Round 541 two large crickets meet  [ 153 3392] [0.04315938 0.95684062]
# Round 542 two large crickets meet  [ 153 3398] [0.04308645 0.95691355]
# Round 543 a small meets a large    [ 154 3406] [0.04325843 0.95674157]
# Round 544 two large crickets meet  [ 154 3412] [0.04318564 0.95681436]
# Round 545 a small meets a large    [ 155 3420] [0.04335664 0.95664336]
# Round 546 two large crickets meet  [ 155 3426] [0.043284 0.956716]
# Round 547 two large crickets meet  [ 155 3432] [0.0432116 0.9567884]
# Round 548 two large crickets meet  [ 155 3438] [0.04313944 0.95686056]
# Round 549 two large crickets meet  [ 155 3444] [0.04306752 0.95693248]
# Round 550 two large crickets meet  [ 155 3450] [0.04299584 0.95700416]
# Round 551 two large crickets meet  [ 155 3456] [0.0429244 0.9570756]
# Round 552 two large crickets meet  [ 155 3462] [0.04285319 0.95714681]
# Round 553 two large crickets meet  [ 155 3468] [0.04278222 0.95721778]
# Round 554 two large crickets meet  [ 155 3474] [0.04271149 0.95728851]
# Round 555 two large crickets meet  [ 155 3480] [0.04264099 0.95735901]
# Round 556 two large crickets meet  [ 155 3486] [0.04257072 0.95742928]
# Round 557 two large crickets meet  [ 155 3492] [0.04250069 0.95749931]
# Round 558 two large crickets meet  [ 155 3498] [0.04243088 0.95756912]
# Round 559 two large crickets meet  [ 155 3504] [0.0423613 0.9576387]
# Round 560 two large crickets meet  [ 155 3510] [0.04229195 0.95770805]
# Round 561 two large crickets meet  [ 155 3516] [0.04222283 0.95777717]
# Round 562 two large crickets meet  [ 155 3522] [0.04215393 0.95784607]
# Round 563 two large crickets meet  [ 155 3528] [0.04208526 0.95791474]
# Round 564 two large crickets meet  [ 155 3534] [0.04201681 0.95798319]
# Round 565 two large crickets meet  [ 155 3540] [0.04194858 0.95805142]
# Round 566 two large crickets meet  [ 155 3546] [0.04188057 0.95811943]
# Round 567 two large crickets meet  [ 155 3552] [0.04181279 0.95818721]
# Round 568 two large crickets meet  [ 155 3558] [0.04174522 0.95825478]
# Round 569 two large crickets meet  [ 155 3564] [0.04167787 0.95832213]
# Round 570 two large crickets meet  [ 155 3570] [0.04161074 0.95838926]
# Round 571 two large crickets meet  [ 155 3576] [0.04154382 0.95845618]
# Round 572 two large crickets meet  [ 155 3582] [0.04147712 0.95852288]
# Round 573 two large crickets meet  [ 155 3588] [0.04141063 0.95858937]
# Round 574 two large crickets meet  [ 155 3594] [0.04134436 0.95865564]
# Round 575 two large crickets meet  [ 155 3600] [0.0412783 0.9587217]
# Round 576 two large crickets meet  [ 155 3606] [0.04121244 0.95878756]
# Round 577 two large crickets meet  [ 155 3612] [0.0411468 0.9588532]
# Round 578 two large crickets meet  [ 155 3618] [0.04108137 0.95891863]
# Round 579 two large crickets meet  [ 155 3624] [0.04101614 0.95898386]
# Round 580 two large crickets meet  [ 155 3630] [0.04095112 0.95904888]
# Round 581 two large crickets meet  [ 155 3636] [0.04088631 0.95911369]
# Round 582 two large crickets meet  [ 155 3642] [0.0408217 0.9591783]
# Round 583 a small meets a large    [ 156 3650] [0.04098791 0.95901209]
# Round 584 two large crickets meet  [ 156 3656] [0.0409234 0.9590766]
# Round 585 two large crickets meet  [ 156 3662] [0.04085909 0.95914091]
# Round 586 two large crickets meet  [ 156 3668] [0.04079498 0.95920502]
# Round 587 two large crickets meet  [ 156 3674] [0.04073107 0.95926893]
# Round 588 two large crickets meet  [ 156 3680] [0.04066736 0.95933264]
# Round 589 a small meets a large    [ 157 3688] [0.04083225 0.95916775]
# Round 590 two large crickets meet  [ 157 3694] [0.04076863 0.95923137]
# Round 591 two large crickets meet  [ 157 3700] [0.04070521 0.95929479]
# Round 592 two large crickets meet  [ 157 3706] [0.04064199 0.95935801]
# Round 593 two large crickets meet  [ 157 3712] [0.04057896 0.95942104]
# Round 594 two large crickets meet  [ 157 3718] [0.04051613 0.95948387]
# Round 595 two large crickets meet  [ 157 3724] [0.04045349 0.95954651]
# Round 596 two large crickets meet  [ 157 3730] [0.04039105 0.95960895]
# Round 597 two large crickets meet  [ 157 3736] [0.0403288 0.9596712]
# Round 598 two large crickets meet  [ 157 3742] [0.04026674 0.95973326]
# Round 599 two large crickets meet  [ 157 3748] [0.04020487 0.95979513]
# Round 600 two large crickets meet  [ 157 3754] [0.04014319 0.95985681]
# Round 601 two large crickets meet  [ 157 3760] [0.0400817 0.9599183]
# Round 602 two large crickets meet  [ 157 3766] [0.04002039 0.95997961]
# Round 603 two large crickets meet  [ 157 3772] [0.03995928 0.96004072]
# Round 604 two large crickets meet  [ 157 3778] [0.03989835 0.96010165]
# Round 605 two large crickets meet  [ 157 3784] [0.0398376 0.9601624]
# Round 606 two large crickets meet  [ 157 3790] [0.03977705 0.96022295]
# Round 607 two large crickets meet  [ 157 3796] [0.03971667 0.96028333]
# Round 608 two large crickets meet  [ 157 3802] [0.03965648 0.96034352]
# Round 609 two large crickets meet  [ 157 3808] [0.03959647 0.96040353]
# Round 610 two large crickets meet  [ 157 3814] [0.03953664 0.96046336]
# Round 611 two large crickets meet  [ 157 3820] [0.03947699 0.96052301]
# Round 612 two large crickets meet  [ 157 3826] [0.03941752 0.96058248]
# Round 613 a small meets a large    [ 158 3834] [0.03957916 0.96042084]
# Round 614 two large crickets meet  [ 158 3840] [0.03951976 0.96048024]
# Round 615 two large crickets meet  [ 158 3846] [0.03946054 0.96053946]
# Round 616 two large crickets meet  [ 158 3852] [0.0394015 0.9605985]
# Round 617 two small crickets meet  [ 168 3852] [0.04179104 0.95820896]
# Round 618 two large crickets meet  [ 168 3858] [0.04172876 0.95827124]
# Round 619 two large crickets meet  [ 168 3864] [0.04166667 0.95833333]
# Round 620 two large crickets meet  [ 168 3870] [0.04160475 0.95839525]
# Round 621 two large crickets meet  [ 168 3876] [0.04154303 0.95845697]
# Round 622 two large crickets meet  [ 168 3882] [0.04148148 0.95851852]
# Round 623 two large crickets meet  [ 168 3888] [0.04142012 0.95857988]
# Round 624 two large crickets meet  [ 168 3894] [0.04135894 0.95864106]
# Round 625 two large crickets meet  [ 168 3900] [0.04129794 0.95870206]
# Round 626 two large crickets meet  [ 168 3906] [0.04123711 0.95876289]
# Round 627 two large crickets meet  [ 168 3912] [0.04117647 0.95882353]
# Round 628 two large crickets meet  [ 168 3918] [0.04111601 0.95888399]
# Round 629 two large crickets meet  [ 168 3924] [0.04105572 0.95894428]
# Round 630 two large crickets meet  [ 168 3930] [0.04099561 0.95900439]
# Round 631 two large crickets meet  [ 168 3936] [0.04093567 0.95906433]
# Round 632 two large crickets meet  [ 168 3942] [0.04087591 0.95912409]
# Round 633 two large crickets meet  [ 168 3948] [0.04081633 0.95918367]
# Round 634 two large crickets meet  [ 168 3954] [0.04075691 0.95924309]
# Round 635 two large crickets meet  [ 168 3960] [0.04069767 0.95930233]
# Round 636 two large crickets meet  [ 168 3966] [0.04063861 0.95936139]
# Round 637 two large crickets meet  [ 168 3972] [0.04057971 0.95942029]
# Round 638 two large crickets meet  [ 168 3978] [0.04052098 0.95947902]
# Round 639 two large crickets meet  [ 168 3984] [0.04046243 0.95953757]
# Round 640 a small meets a large    [ 169 3992] [0.04061524 0.95938476]
# Round 641 two large crickets meet  [ 169 3998] [0.04055676 0.95944324]
# Round 642 two large crickets meet  [ 169 4004] [0.04049844 0.95950156]
# Round 643 two large crickets meet  [ 169 4010] [0.0404403 0.9595597]
# Round 644 two large crickets meet  [ 169 4016] [0.04038232 0.95961768]
# Round 645 two large crickets meet  [ 169 4022] [0.0403245 0.9596755]
# Round 646 two large crickets meet  [ 169 4028] [0.04026686 0.95973314]
# Round 647 two large crickets meet  [ 169 4034] [0.04020937 0.95979063]
# Round 648 two large crickets meet  [ 169 4040] [0.04015206 0.95984794]
# Round 649 a small meets a large    [ 170 4048] [0.04030346 0.95969654]
# Round 650 a small meets a large    [ 171 4056] [0.04045422 0.95954578]
# Round 651 two large crickets meet  [ 171 4062] [0.04039688 0.95960312]
# Round 652 a small meets a large    [ 172 4070] [0.04054691 0.95945309]
# Round 653 two large crickets meet  [ 172 4076] [0.04048964 0.95951036]
# Round 654 a small meets a large    [ 173 4084] [0.04063895 0.95936105]
# Round 655 two large crickets meet  [ 173 4090] [0.04058175 0.95941825]
# Round 656 two large crickets meet  [ 173 4096] [0.04052471 0.95947529]
# Round 657 two large crickets meet  [ 173 4102] [0.04046784 0.95953216]
# Round 658 two large crickets meet  [ 173 4108] [0.04041112 0.95958888]
# Round 659 two large crickets meet  [ 173 4114] [0.04035456 0.95964544]
# Round 660 two large crickets meet  [ 173 4120] [0.04029816 0.95970184]
# Round 661 two large crickets meet  [ 173 4126] [0.04024192 0.95975808]
# Round 662 two large crickets meet  [ 173 4132] [0.04018583 0.95981417]
# Round 663 two large crickets meet  [ 173 4138] [0.0401299 0.9598701]
# Round 664 two large crickets meet  [ 173 4144] [0.04007413 0.95992587]
# Round 665 two large crickets meet  [ 173 4150] [0.04001851 0.95998149]
# Round 666 two large crickets meet  [ 173 4156] [0.03996304 0.96003696]
# Round 667 two large crickets meet  [ 173 4162] [0.03990773 0.96009227]
# Round 668 two large crickets meet  [ 173 4168] [0.03985257 0.96014743]
# Round 669 two large crickets meet  [ 173 4174] [0.03979756 0.96020244]
# Round 670 two large crickets meet  [ 173 4180] [0.03974271 0.96025729]
# Round 671 two large crickets meet  [ 173 4186] [0.039688 0.960312]
# Round 672 two large crickets meet  [ 173 4192] [0.03963345 0.96036655]
# Round 673 two large crickets meet  [ 173 4198] [0.03957904 0.96042096]
# Round 674 two large crickets meet  [ 173 4204] [0.03952479 0.96047521]
# Round 675 two large crickets meet  [ 173 4210] [0.03947068 0.96052932]
# Round 676 two large crickets meet  [ 173 4216] [0.03941672 0.96058328]
# Round 677 two large crickets meet  [ 173 4222] [0.03936291 0.96063709]
# Round 678 two large crickets meet  [ 173 4228] [0.03930925 0.96069075]
# Round 679 two large crickets meet  [ 173 4234] [0.03925573 0.96074427]
# Round 680 two large crickets meet  [ 173 4240] [0.03920236 0.96079764]
# Round 681 two large crickets meet  [ 173 4246] [0.03914913 0.96085087]
# Round 682 two large crickets meet  [ 173 4252] [0.03909605 0.96090395]
# Round 683 two large crickets meet  [ 173 4258] [0.03904311 0.96095689]
# Round 684 two large crickets meet  [ 173 4264] [0.03899031 0.96100969]
# Round 685 two large crickets meet  [ 173 4270] [0.03893765 0.96106235]
# Round 686 two large crickets meet  [ 173 4276] [0.03888514 0.96111486]
# Round 687 two large crickets meet  [ 173 4282] [0.03883277 0.96116723]
# Round 688 two large crickets meet  [ 173 4288] [0.03878054 0.96121946]
# Round 689 a small meets a large    [ 174 4296] [0.03892617 0.96107383]
# Round 690 two large crickets meet  [ 174 4302] [0.03887399 0.96112601]
# Round 691 two large crickets meet  [ 174 4308] [0.03882195 0.96117805]
# Round 692 two large crickets meet  [ 174 4314] [0.03877005 0.96122995]
# Round 693 two large crickets meet  [ 174 4320] [0.03871829 0.96128171]
# Round 694 two large crickets meet  [ 174 4326] [0.03866667 0.96133333]
# Round 695 two large crickets meet  [ 174 4332] [0.03861518 0.96138482]
# Round 696 two large crickets meet  [ 174 4338] [0.03856383 0.96143617]
# Round 697 two large crickets meet  [ 174 4344] [0.03851262 0.96148738]
# Round 698 two large crickets meet  [ 174 4350] [0.03846154 0.96153846]
# Round 699 two large crickets meet  [ 174 4356] [0.0384106 0.9615894]
# Round 700 two large crickets meet  [ 174 4362] [0.03835979 0.96164021]
# Round 701 two large crickets meet  [ 174 4368] [0.03830911 0.96169089]
# Round 702 a small meets a large    [ 175 4376] [0.03845309 0.96154691]
# Round 703 two large crickets meet  [ 175 4382] [0.03840246 0.96159754]
# Round 704 two large crickets meet  [ 175 4388] [0.03835196 0.96164804]
# Round 705 two large crickets meet  [ 175 4394] [0.0383016 0.9616984]
# Round 706 two large crickets meet  [ 175 4400] [0.03825137 0.96174863]
# Round 707 two large crickets meet  [ 175 4406] [0.03820127 0.96179873]
# Round 708 two large crickets meet  [ 175 4412] [0.0381513 0.9618487]
# Round 709 two large crickets meet  [ 175 4418] [0.03810146 0.96189854]
# Round 710 a small meets a large    [ 176 4426] [0.03824424 0.96175576]
# Round 711 two large crickets meet  [ 176 4432] [0.03819444 0.96180556]
# Round 712 two large crickets meet  [ 176 4438] [0.03814478 0.96185522]
# Round 713 two large crickets meet  [ 176 4444] [0.03809524 0.96190476]
# Round 714 two large crickets meet  [ 176 4450] [0.03804583 0.96195417]
# Round 715 two large crickets meet  [ 176 4456] [0.03799655 0.96200345]
# Round 716 two large crickets meet  [ 176 4462] [0.03794739 0.96205261]
# Round 717 a small meets a large    [ 177 4470] [0.03808909 0.96191091]
# Round 718 two large crickets meet  [ 177 4476] [0.03803997 0.96196003]
# Round 719 two large crickets meet  [ 177 4482] [0.03799099 0.96200901]
# Round 720 two large crickets meet  [ 177 4488] [0.03794212 0.96205788]
# Round 721 two large crickets meet  [ 177 4494] [0.03789338 0.96210662]
# Round 722 two large crickets meet  [ 177 4500] [0.03784477 0.96215523]
# Round 723 two large crickets meet  [ 177 4506] [0.03779628 0.96220372]
# Round 724 two large crickets meet  [ 177 4512] [0.03774792 0.96225208]
# Round 725 two large crickets meet  [ 177 4518] [0.03769968 0.96230032]
# Round 726 two large crickets meet  [ 177 4524] [0.03765156 0.96234844]
# Round 727 two large crickets meet  [ 177 4530] [0.03760357 0.96239643]
# Round 728 a small meets a large    [ 178 4538] [0.03774385 0.96225615]
# Round 729 a small meets a large    [ 179 4546] [0.0378836 0.9621164]
# Round 730 two large crickets meet  [ 179 4552] [0.03783555 0.96216445]
# Round 731 two large crickets meet  [ 179 4558] [0.03778763 0.96221237]
# Round 732 two large crickets meet  [ 179 4564] [0.03773983 0.96226017]
# Round 733 two large crickets meet  [ 179 4570] [0.03769215 0.96230785]
# Round 734 two large crickets meet  [ 179 4576] [0.03764458 0.96235542]
# Round 735 two large crickets meet  [ 179 4582] [0.03759714 0.96240286]
# Round 736 two large crickets meet  [ 179 4588] [0.03754982 0.96245018]
# Round 737 two large crickets meet  [ 179 4594] [0.03750262 0.96249738]
# Round 738 two large crickets meet  [ 179 4600] [0.03745553 0.96254447]
# Round 739 two large crickets meet  [ 179 4606] [0.03740857 0.96259143]
# Round 740 two large crickets meet  [ 179 4612] [0.03736172 0.96263828]
# Round 741 two large crickets meet  [ 179 4618] [0.03731499 0.96268501]
# Round 742 two large crickets meet  [ 179 4624] [0.03726837 0.96273163]
# Round 743 two large crickets meet  [ 179 4630] [0.03722188 0.96277812]
# Round 744 two large crickets meet  [ 179 4636] [0.03717549 0.96282451]
# Round 745 two large crickets meet  [ 179 4642] [0.03712923 0.96287077]
# Round 746 two large crickets meet  [ 179 4648] [0.03708307 0.96291693]
# Round 747 two large crickets meet  [ 179 4654] [0.03703704 0.96296296]
# Round 748 two large crickets meet  [ 179 4660] [0.03699111 0.96300889]
# Round 749 two large crickets meet  [ 179 4666] [0.0369453 0.9630547]
# Round 750 a small meets a large    [ 180 4674] [0.03708282 0.96291718]
# Round 751 two large crickets meet  [ 180 4680] [0.03703704 0.96296296]
# Round 752 two large crickets meet  [ 180 4686] [0.03699137 0.96300863]
# Round 753 two large crickets meet  [ 180 4692] [0.03694581 0.96305419]
# Round 754 two large crickets meet  [ 180 4698] [0.03690037 0.96309963]
# Round 755 two large crickets meet  [ 180 4704] [0.03685504 0.96314496]
# Round 756 two large crickets meet  [ 180 4710] [0.03680982 0.96319018]
# Round 757 two large crickets meet  [ 180 4716] [0.03676471 0.96323529]
# Round 758 two large crickets meet  [ 180 4722] [0.03671971 0.96328029]
# Round 759 two large crickets meet  [ 180 4728] [0.03667482 0.96332518]
# Round 760 two large crickets meet  [ 180 4734] [0.03663004 0.96336996]
# Round 761 two large crickets meet  [ 180 4740] [0.03658537 0.96341463]
# Round 762 a small meets a large    [ 181 4748] [0.03672144 0.96327856]
# Round 763 two large crickets meet  [ 181 4754] [0.0366768 0.9633232]
# Round 764 two large crickets meet  [ 181 4760] [0.03663226 0.96336774]
# Round 765 two large crickets meet  [ 181 4766] [0.03658783 0.96341217]
# Round 766 a small meets a large    [ 182 4774] [0.03672316 0.96327684]
# Round 767 two large crickets meet  [ 182 4780] [0.03667876 0.96332124]
# Round 768 two large crickets meet  [ 182 4786] [0.03663446 0.96336554]
# Round 769 two large crickets meet  [ 182 4792] [0.03659027 0.96340973]
# Round 770 two large crickets meet  [ 182 4798] [0.03654618 0.96345382]
# Round 771 two large crickets meet  [ 182 4804] [0.03650221 0.96349779]
# Round 772 two large crickets meet  [ 182 4810] [0.03645833 0.96354167]
# Round 773 two large crickets meet  [ 182 4816] [0.03641457 0.96358543]
# Round 774 two large crickets meet  [ 182 4822] [0.0363709 0.9636291]
# Round 775 two large crickets meet  [ 182 4828] [0.03632735 0.96367265]
# Round 776 two large crickets meet  [ 182 4834] [0.03628389 0.96371611]
# Round 777 two large crickets meet  [ 182 4840] [0.03624054 0.96375946]
# Round 778 two large crickets meet  [ 182 4846] [0.0361973 0.9638027]
# Round 779 two large crickets meet  [ 182 4852] [0.03615415 0.96384585]
# Round 780 two large crickets meet  [ 182 4858] [0.03611111 0.96388889]
# Round 781 two large crickets meet  [ 182 4864] [0.03606817 0.96393183]
# Round 782 two large crickets meet  [ 182 4870] [0.03602534 0.96397466]
# Round 783 two large crickets meet  [ 182 4876] [0.0359826 0.9640174]
# Round 784 two large crickets meet  [ 182 4882] [0.03593997 0.96406003]
# Round 785 two large crickets meet  [ 182 4888] [0.03589744 0.96410256]
# Round 786 a small meets a large    [ 183 4896] [0.03603071 0.96396929]
# Round 787 two large crickets meet  [ 183 4902] [0.0359882 0.9640118]
# Round 788 two large crickets meet  [ 183 4908] [0.03594579 0.96405421]
# Round 789 two large crickets meet  [ 183 4914] [0.03590347 0.96409653]
# Round 790 two large crickets meet  [ 183 4920] [0.03586126 0.96413874]
# Round 791 two large crickets meet  [ 183 4926] [0.03581914 0.96418086]
# Round 792 two large crickets meet  [ 183 4932] [0.03577713 0.96422287]
# Round 793 two large crickets meet  [ 183 4938] [0.03573521 0.96426479]
# Round 794 two large crickets meet  [ 183 4944] [0.03569339 0.96430661]
# Round 795 two large crickets meet  [ 183 4950] [0.03565167 0.96434833]
# Round 796 two large crickets meet  [ 183 4956] [0.03561004 0.96438996]
# Round 797 a small meets a large    [ 184 4964] [0.03574204 0.96425796]
# Round 798 two large crickets meet  [ 184 4970] [0.03570043 0.96429957]
# Round 799 two large crickets meet  [ 184 4976] [0.03565891 0.96434109]
# Round 800 a small meets a large    [ 185 4984] [0.03579029 0.96420971]
# Round 801 two large crickets meet  [ 185 4990] [0.03574879 0.96425121]
# Round 802 two large crickets meet  [ 185 4996] [0.03570739 0.96429261]
# Round 803 two large crickets meet  [ 185 5002] [0.03566609 0.96433391]
# Round 804 two large crickets meet  [ 185 5008] [0.03562488 0.96437512]
# Round 805 two large crickets meet  [ 185 5014] [0.03558377 0.96441623]
# Round 806 two large crickets meet  [ 185 5020] [0.03554275 0.96445725]
# Round 807 a small meets a large    [ 186 5028] [0.03567319 0.96432681]
# Round 808 two large crickets meet  [ 186 5034] [0.03563218 0.96436782]
# Round 809 two large crickets meet  [ 186 5040] [0.03559127 0.96440873]
# Round 810 two large crickets meet  [ 186 5046] [0.03555046 0.96444954]
# Round 811 a small meets a large    [ 187 5054] [0.03568021 0.96431979]
# Round 812 two large crickets meet  [ 187 5060] [0.03563941 0.96436059]
# Round 813 two large crickets meet  [ 187 5066] [0.03559871 0.96440129]
# Round 814 two large crickets meet  [ 187 5072] [0.03555809 0.96444191]
# Round 815 two large crickets meet  [ 187 5078] [0.03551757 0.96448243]
# Round 816 two large crickets meet  [ 187 5084] [0.03547714 0.96452286]
# Round 817 two large crickets meet  [ 187 5090] [0.0354368 0.9645632]
# Round 818 two large crickets meet  [ 187 5096] [0.03539655 0.96460345]
# Round 819 two large crickets meet  [ 187 5102] [0.0353564 0.9646436]
# Round 820 two large crickets meet  [ 187 5108] [0.03531634 0.96468366]
# Round 821 a small meets a large    [ 188 5116] [0.03544495 0.96455505]
# Round 822 two large crickets meet  [ 188 5122] [0.0354049 0.9645951]
# Round 823 two large crickets meet  [ 188 5128] [0.03536494 0.96463506]
# Round 824 two large crickets meet  [ 188 5134] [0.03532507 0.96467493]
# Round 825 two large crickets meet  [ 188 5140] [0.03528529 0.96471471]
# Round 826 two large crickets meet  [ 188 5146] [0.03524559 0.96475441]
# Round 827 two large crickets meet  [ 188 5152] [0.03520599 0.96479401]
# Round 828 two large crickets meet  [ 188 5158] [0.03516648 0.96483352]
# Round 829 two large crickets meet  [ 188 5164] [0.03512706 0.96487294]
# Round 830 two large crickets meet  [ 188 5170] [0.03508772 0.96491228]
# Round 831 two large crickets meet  [ 188 5176] [0.03504847 0.96495153]
# Round 832 a small meets a large    [ 189 5184] [0.03517588 0.96482412]
# Round 833 two large crickets meet  [ 189 5190] [0.03513664 0.96486336]
# Round 834 two large crickets meet  [ 189 5196] [0.03509749 0.96490251]
# Round 835 two large crickets meet  [ 189 5202] [0.03505843 0.96494157]
# Round 836 two large crickets meet  [ 189 5208] [0.03501946 0.96498054]
# Round 837 two large crickets meet  [ 189 5214] [0.03498057 0.96501943]
# Round 838 two large crickets meet  [ 189 5220] [0.03494176 0.96505824]
# Round 839 two large crickets meet  [ 189 5226] [0.03490305 0.96509695]
# Round 840 two large crickets meet  [ 189 5232] [0.03486442 0.96513558]
# Round 841 two large crickets meet  [ 189 5238] [0.03482587 0.96517413]
# Round 842 two large crickets meet  [ 189 5244] [0.03478741 0.96521259]
# Round 843 two large crickets meet  [ 189 5250] [0.03474903 0.96525097]
# Round 844 two large crickets meet  [ 189 5256] [0.03471074 0.96528926]
# Round 845 two large crickets meet  [ 189 5262] [0.03467254 0.96532746]
# Round 846 two large crickets meet  [ 189 5268] [0.03463441 0.96536559]
# Round 847 two large crickets meet  [ 189 5274] [0.03459638 0.96540362]
# Round 848 two large crickets meet  [ 189 5280] [0.03455842 0.96544158]
# Round 849 two large crickets meet  [ 189 5286] [0.03452055 0.96547945]
# Round 850 two large crickets meet  [ 189 5292] [0.03448276 0.96551724]
# Round 851 two large crickets meet  [ 189 5298] [0.03444505 0.96555495]
# Round 852 two large crickets meet  [ 189 5304] [0.03440743 0.96559257]
# Round 853 two large crickets meet  [ 189 5310] [0.03436989 0.96563011]
# Round 854 two large crickets meet  [ 189 5316] [0.03433243 0.96566757]
# Round 855 two large crickets meet  [ 189 5322] [0.03429505 0.96570495]
# Round 856 two large crickets meet  [ 189 5328] [0.03425775 0.96574225]
# Round 857 two large crickets meet  [ 189 5334] [0.03422053 0.96577947]
# Round 858 two large crickets meet  [ 189 5340] [0.0341834 0.9658166]
# Round 859 two large crickets meet  [ 189 5346] [0.03414634 0.96585366]
# Round 860 two large crickets meet  [ 189 5352] [0.03410937 0.96589063]
# Round 861 two large crickets meet  [ 189 5358] [0.03407247 0.96592753]
# Round 862 two large crickets meet  [ 189 5364] [0.03403566 0.96596434]
# Round 863 two large crickets meet  [ 189 5370] [0.03399892 0.96600108]
# Round 864 two large crickets meet  [ 189 5376] [0.03396226 0.96603774]
# Round 865 two large crickets meet  [ 189 5382] [0.03392569 0.96607431]
# Round 866 two large crickets meet  [ 189 5388] [0.03388919 0.96611081]
# Round 867 two large crickets meet  [ 189 5394] [0.03385277 0.96614723]
# Round 868 two large crickets meet  [ 189 5400] [0.03381643 0.96618357]
# Round 869 two large crickets meet  [ 189 5406] [0.03378016 0.96621984]
# Round 870 two large crickets meet  [ 189 5412] [0.03374397 0.96625603]
# Round 871 two large crickets meet  [ 189 5418] [0.03370787 0.96629213]
# Round 872 two large crickets meet  [ 189 5424] [0.03367183 0.96632817]
# Round 873 two large crickets meet  [ 189 5430] [0.03363588 0.96636412]
# Round 874 two large crickets meet  [ 189 5436] [0.0336 0.9664]
# Round 875 two large crickets meet  [ 189 5442] [0.0335642 0.9664358]
# Round 876 two large crickets meet  [ 189 5448] [0.03352847 0.96647153]
# Round 877 two large crickets meet  [ 189 5454] [0.03349282 0.96650718]
# Round 878 two large crickets meet  [ 189 5460] [0.03345725 0.96654275]
# Round 879 two large crickets meet  [ 189 5466] [0.03342175 0.96657825]
# Round 880 two large crickets meet  [ 189 5472] [0.03338633 0.96661367]
# Round 881 two large crickets meet  [ 189 5478] [0.03335098 0.96664902]
# Round 882 two large crickets meet  [ 189 5484] [0.03331571 0.96668429]
# Round 883 two large crickets meet  [ 189 5490] [0.03328051 0.96671949]
# Round 884 two large crickets meet  [ 189 5496] [0.03324538 0.96675462]
# Round 885 two large crickets meet  [ 189 5502] [0.03321033 0.96678967]
# Round 886 two large crickets meet  [ 189 5508] [0.03317536 0.96682464]
# Round 887 two large crickets meet  [ 189 5514] [0.03314045 0.96685955]
# Round 888 two large crickets meet  [ 189 5520] [0.03310562 0.96689438]
# Round 889 two large crickets meet  [ 189 5526] [0.03307087 0.96692913]
# Round 890 two large crickets meet  [ 189 5532] [0.03303618 0.96696382]
# Round 891 two large crickets meet  [ 189 5538] [0.03300157 0.96699843]
# Round 892 two large crickets meet  [ 189 5544] [0.03296703 0.96703297]
# Round 893 two large crickets meet  [ 189 5550] [0.03293257 0.96706743]
# Round 894 two large crickets meet  [ 189 5556] [0.03289817 0.96710183]
# Round 895 two large crickets meet  [ 189 5562] [0.03286385 0.96713615]
# Round 896 two large crickets meet  [ 189 5568] [0.0328296 0.9671704]
# Round 897 two large crickets meet  [ 189 5574] [0.03279542 0.96720458]
# Round 898 two large crickets meet  [ 189 5580] [0.03276131 0.96723869]
# Round 899 two large crickets meet  [ 189 5586] [0.03272727 0.96727273]
# Round 900 two large crickets meet  [ 189 5592] [0.03269331 0.96730669]

# %% [markdown]
# The above simulation displays, after each encounter, the number of individuals of each type and the fraction of individuals of each type.   Run the simulation multiple times for different initial conditions.
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 2:</SPAN>**  Answer the following questions.   You do not need to provide code for this problem, but explain your answers.
# <ol>
# <li> How quickly does the total population grow if initally all the crickets are small?
# <li> How quickly does the total population grow if initally all the crickets are large?
# <li> Do the fractions converge to a stable equilibrium in which the fractions of both small and large crickets are nonzero? (To explore convergence you may need to increase the number of encounters simulated.)
# </ol>

# %% [markdown]
# __Answer:__ (Your answer here)

# %% [markdown]
# Q1: After every encounter there will be 10 more small crickets.<br>
# Q2: After every encounter there will be 6 more large crickets.<br>
# Q3: By running large number different times, I don't see it will reach a stable equilibrium.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 2</SPAN>**

# %% [markdown]
# The code given next is essentially the same as above.  One difference is a time variable is added such that the average rate that an individual cricket has encounters is proportional to the total number of crickets.  This results in exponential growth of the population with time.    Another difference is that population sizes are saved and plotted.

# %%
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted

F=np.array([[5,1],[8,3]])  # fitness matrix
n_max=100  # maximum number of interactions
n=np.zeros((n_max,2),dtype=float)
time=np.zeros(n_max,dtype=float)

n[0,0], n[0,1] = 10,1 # initial [number of small crickets, number of large crickets]

for k in range(n_max-1):
    time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
    a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
    b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n[k+1,:]= n[k,:] + [2*F[0,0],0]
    elif a<U<=a+b:
        n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
    else:
        n[k+1,:]= n[k,:] + [0,2*F[1,1]]

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.text(1.1,n[80,0], r'small',fontsize=14)
plt.text(1.1,n[80,1], r'large',fontsize=14)
plt.xlabel('time')
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (simulation)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (simulation)')

# %% [markdown]
# The following code computes the deterministic analog of the cricket evolution.  The basic idea is that if the current population is [n[0], n[1]] then the drift (i.e. the expected rate of increase) of n[0] is n[0]  multiplied by the expected number of small crickets generated by a small cricket if an encounter happens.  That is true because each of the existing small crikets is having encounters at expected rate one.   To calculate the mean number of new small crickets generated by the encounter of a small cricket with a randomly selected other cricket, we use the law of total probability.  The encountered cricket is type zero with probabiity n[0]/(n[0]+n[1]), which results in F[0,0] new crickets of type zero, and the encountered cricket is type one with probability n[1]/(n[0]+n[1]), which results in F[0,1] new crickets of type zero.   Combining we get
# $$
# \dot{n}[0] = n[0]*(F[0,0]*n[0]+F[0,1]*n[1])/(n[0]+n[1])
# $$
# The equation just derived is based on the law of large numbers (LLN).  If the population is fairly large then no one individual plays a major role in the evolution.  Over a small period of time the ratios of small and large crickets is nearly constant, so the number of new crickets of each type in each time slot are nearly independent and identically distributed.   The LLN suggests approximating the sum of number of individuals of each type by the expected numbers of individuals of each type.  That's how we arrive at a deterministic differential equation.
#
# A similar expression holds for the derivative of n[1], and the two equations can be writen in matrix form as
# $$
# \dot{n} = diag(n)*F*n/sum(n)
# $$
# where diag(n) is the diagonal matrix with n[0] and n[1] on the diagonal, and "$*$" represents usual matrix multiplication.   (In the python code below, "$*$" denotes element by element multiplication, which is used instead of creating a diagonal matrix, and np.dot is used for ordinary matrix multiplication.)

# %%
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (ode prediction)')

# %% [markdown]
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 3:</SPAN>** Run the code above and compare the output to the output of the previous code for stochastic evolutionary dynamics.  Try different intial conditions such as [0,4], [4,0], and [10,1]. Comment on how the result of this compares to our previous simulation. Is the behavior similar?

# %% [markdown]
# __Answer__: (Your answer here)

# %%
# Deterministic (ODE) replicator dynamics for cricket game
# [0,4]case
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[0,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (ode prediction)')

# %%
# Deterministic (ODE) replicator dynamics for cricket game
# [4,0]case
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[4,0]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (ode prediction)')

# %%
# Deterministic (ODE) replicator dynamics for cricket game
# [10,1]case
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[10,1]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (ode prediction)')

# %% [markdown]
# If the initial condition is [0,4] or [4,0], the output is the same as the previous problem. Because large or small will always be 0.<br>
# Nevertheless, if the initial condition is [10,1], the result becomes different, not the same as [10,1] simulation above, that is because the result here will depend on current state.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 3</SPAN>**

# %% [markdown]
# If we let $\theta[0]=\frac{n[0]}{n[0]+n[1]}$ and $\theta[1]=\frac{n[1]}{n[0]+n[1]}$ then the vector $\theta=\binom{\theta[0]}{\theta[1]}$ describes the fractions of the popuation of each type.  It's entries sum to one.  Using the chain rule of calculus we can derive the following differential equation for $\theta$ from the above ode for $n$:
# $$
# \dot{\theta} = diag(\theta) \left( F\theta - \mathbf{1} \theta^T F \theta \right)
# $$
# where $\mathbf{1}$ is the column vector of ones (the derivation is a bit involved, try deriving it by yourself if interested, but it is not required). The two components of the vector $F \theta$ give the average fitness level of small crickets and large crickets, respectively, in an encounter with a cricket selected randomly from the population.   And $\theta^T F \theta$ is the weighted average of that vector, giving the average fitness over all crickets in the population.   Thus, $\theta[0]$ is increasing exactly when the fitness of small crickets is greater than the average fitness.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 4:</SPAN>**
#
# 1. Modify the above code to integrate the equation for the $\theta$ vector to obtain $\theta$ vs. time.
# To check your answer, compare it to what you get by first computing the trajectory of $n$ and then calculating $\theta$ from $n.$  (The code given above for deterministic evolution of n works for any number of types, not just two types. A problem below involves three types of individuals, so it'd be nice if you could implement your code for computing $\theta$ to work for any number of types.) __Be careful when you write your program, since matrix multiplication in Python can be tricky. Understand "$*$" multiplication and np.dot multiplication first. After each small step, debug, confirm, then proceed.__
# 2. Using the fact that $\theta[1]=1-\theta[0],$  a differential equation can be derived for the variable $\theta[0]$ alone.
# Plot the function $h$ on the interval $[0,1]$ such that $\dot{\theta}[0]=h(\theta[0]).$ Note that the horizontal axis of the graph is $\theta$, the vertical axis is $\dot{\theta}$. (You can just do this
# numerically.  It can also be done algebrically; in fact $h$ is a cubic polynomial, but it is a bit complicated to find the polynomial.)
# 3. What are the zeroes of $h$ (those are the equilibrium points of $\theta[0]$)?  Which of those are stable (in the sense that if $\theta[0]$ is slightly moved away from the equilibrium point, it returns to the equilibrium point)?

# %% [markdown]
# __Answer:__ (Your answer here)

# %%
# Problem 4.1
# differential equation for theta

F=np.array([[5,1],[8,3]])  # fitness matrix

def new_f(theta,t):
    return theta*(np.dot(F,theta)-np.dot(np.transpose(theta),np.dot(F,theta)))

thetainit=[10/11,1/11]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,3.0, 1000)

n=odeint(new_f,thetainit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('percentage')
plt.title("percentage of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'percentage of small and large crickets vs. time (ode prediction)')

# %%
#differential equation for n

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[10,1]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,3.0, 1000)

n=odeint(f,ninit,time)
print(n)
for i in range(len(n)):
    temp = n[i,0]
    n[i,0] = n[i,0]/(n[i,0]+n[i,1])
    n[i,1] = n[i,1]/(temp+n[i,1])
plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('percentage')
plt.title("percentage of small and large crickets vs. time (ode prediction)")
# Out:
# [[1.00000000e+01 1.00000000e+00]
#  [1.01401599e+01 1.02291214e+00]
#  [1.02821943e+01 1.04633779e+00]
#  ...
#  [7.89118793e+03 7.88695552e+05]
#  [7.91585989e+03 7.95951050e+05]
#  [7.94060337e+03 8.03272584e+05]]
# Text(0.5, 1.0, 'percentage of small and large crickets vs. time (ode prediction)')

# %%
# Problem 4.2
theta0=np.linspace(0,1,100)
dtheta0 = theta0*(5*theta0+1-theta0-(5*theta0**2+9*theta0*(1-theta0)+3*(1-theta0)**2))
plt.plot(theta0,dtheta0)

# %% [markdown]
# Problem 4.3<br>
# Zeroes are theta=0 or 1. theta=0 is stable, but theta=1 is unstable.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 4</SPAN>**

# %% [markdown]
# The overall behavior in evolutionary games depends heavily on the fitness matrix $F.$   Another choice of $F$ corresponds to the so-called doves and hawks evolution game, for which the fitness matrix is
# $\begin{array}{c|cc}  & dove & hawk  \\ \hline
#     dove & 3 & 1  \\
#     hawk & 5 & 0
#     \end{array}$
# or by a fitness matrix
# $F=\left( \begin{array}{cc}  3 & 1 \\ 5 & 0  \end{array}\right).$   Think of the doves and hawks as two types of birds that need to share resources, such as food.  (The hawks are so aggressive that they attack the doves).  A dove has higher fitness, 3, against another dove than against a hawk, 1.  A hawk has a high fitness against a dove (5) but zero fitness against another hawk, because the hawks fight over their resources.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 5:</SPAN>**
#
# 1. Repeat the deterministic (ode) approach above, but now for the doves and hawks evolution game.   You can use either the random or deterministic evolution equations for the numerical analysis.
# 2. Comment and verify your assertions about equilibrium behavior by finding a differential equation for $\theta[0]$ and exploring its equilbrium points and their stability.

# %% [markdown]
# __Answer__: (Your answer here)

# %%
# Problem 5.1
F=np.array([[3,1],[5,0]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[10,1]    # initial [number of doves, number of hawks]
time=np.linspace(0.0,10, 1000)

n=odeint(f,ninit,time)
print(n)
for i in range(len(n)):
    temp = n[i,0]
    n[i,0] = n[i,0]/(n[i,0]+n[i,1])
    n[i,1] = n[i,1]/(temp+n[i,1])
plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'dove',fontsize=14)
plt.text(1.1,n[800,1], r'hawk',fontsize=14)
plt.ylabel('Fractions')
plt.title("Fractions of dove and hawk vs. time (ode prediction)")
# Out:
# [[1.00000000e+01 1.00000000e+00]
#  [1.02859693e+01 1.04651347e+00]
#  [1.05798102e+01 1.09511122e+00]
#  ...
#  [1.23066636e+09 2.45315582e+09]
#  [1.25138870e+09 2.49451805e+09]
#  [1.27245984e+09 2.53657706e+09]]
# Text(0.5, 1.0, 'Fractions of dove and hawk vs. time (ode prediction)')

# %%
theta=np.linspace(0,1,100)
dtheta = theta*(2*theta+1-(3*theta**2+6*theta*(1-theta)))
plt.plot(theta,dtheta)
plt.xlabel('theta')
plt.ylabel('dtheta')
plt.title("theta vs. dtheta")
# Out:
# Text(0.5, 1.0, 'theta vs. dtheta')

# %% [markdown]
# Problem 5.2<br>
# Zeros are 0, 1/3, 1. $\frac{1}{3}$ is stable, 0,1 are unstable.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 5</SPAN>**

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 6:</SPAN>**  Find a 3x3 fitness matrix $F$ and an initial condition for an evolutionary game with three types of individuals such that the solution $\theta$ has a limit cycle, not just converging to a limit point.  Does the limit cycle depend on the intial state for your fitness matrix?
#
# Hint 1: Adapt the code you wrote for Problem 4.
#
# Hint 2: Solve this problem by trial and error, i.e. trying different values of the entries in the fitness matrix. Think of the three types of individuals as three kinds of animals. What kind of relationship among these three animals would likely to cause an oscillating population for each animal?

# %% [markdown]
# __Answer__: (Your answer here)

# %%
# Your code here
F=np.array([[0,15,-10],[-15,0,10],[10,-15,0]]) 
def f2(theta,t):
    return theta*(np.dot(F,theta)-np.dot(np.transpose(theta),np.dot(F,theta)))
theta_in=[0.1,0.3,0.6]
time=np.linspace(0.0,5, 1000)
n=odeint(f2,theta_in,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.plot(time,n[:,2],'red')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'1',fontsize=14)
plt.text(1.1,n[800,1], r'2',fontsize=14)
plt.text(1.1,n[800,2], r'3',fontsize=14)
plt.ylabel('Fractions')
# Out:
# Text(0, 0.5, 'Fractions')

# %% [markdown]
# If we have 3 kinds of animals A, B, C, and the relationship amoung them is that A is the predator of B, B is the predator of C, and C is the predator of A. It will cause oscillating population of each animals(biology has proved this...)

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 6</SPAN>**

# %% [markdown]
# For this week's lab, please answer all questions 1-6.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ## Academic Integrity Statement ##
#
# By submitting the lab with this statement, you declare you have written up the lab entirely by yourself, including both code and markdown cells. You also agree that you should not share your code with anyone else. Any violation of the academic integrity requirement may cause an academic integrity report to be filed that could go into your student record. See <a href="https://provost.illinois.edu/policies/policies/academic-integrity/students-quick-reference-guide-to-academic-integrity/">Students' Quick Reference Guide to Academic Integrity</a> for more information.
